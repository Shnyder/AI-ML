# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('C:/Users/Dell/Desktop/weather.csv')

# %%
data = data.dropna()

# %%
sns.distplot(data['Rainfall'], bins= 20)
# Out:
# C:\Users\Dell\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.kdeplot(data['Sunshine'], shade=True)

# %%
sns.distplot(data['WindGustSpeed'], hist=False)

# %%
sns.countplot(data['RainToday'])

# %%
sns.boxplot(data['MaxTemp'])

# %%
sns.distplot(data['Sunshine'], kde=False, rug=True)
# Out:
# C:\Users\Dell\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.kdeplot(data['Rainfall'], label='original')
sns.kdeplot(data['Rainfall'], bw=0.2, label='bw=0.2')
sns.kdeplot(data['Rainfall'], bw=2, label='bw=2')
plt.legend()

# %%
plt.figure(figsize=(15,10))
data[['MinTemp','MaxTemp','Date']].plot()

# %%
sns.barplot(x="WindSpeed9am",y="Humidity9am",data=data.iloc[0:50],hue="RainToday")

# %%
t = np.arange(0.0, 2.0, 0.01)
s = 1 + np.sin(2 * np.pi * t)

fig, ax = plt.subplots()
ax.plot(t, s)

ax.set(xlabel='time (s)', ylabel='voltage (mV)',
       title='About as simple as it gets, folks')
ax.grid()

fig.savefig("test.png")
plt.show()

# %%
sns.jointplot(x="Pressure9am", y="Temp9am",kind='hex',
              data=data)
# Out:
# C:\Users\Dell\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# C:\Users\Dell\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.barplot(x="Pressure9am", y="Evaporation",data=data.iloc[0:10],hue='RainTomorrow')

# %%
PressureDate = data.iloc[0:15,0:15]
sns.barplot(x='MaxTemp',y='Date',data=PressureDate)

# %%
sns.distplot(data["Humidity9am"])
# Out:
# C:\Users\Dell\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
plt.figure(figsize=(10,8))
data.plot(kind='scatter', x = 'Sunshine', y = 'Pressure9am')

# %%
sns.boxplot(x='Cloud9am', y='MaxTemp', data=data,hue="RainToday")

# %%
sns.jointplot(x = 'Humidity9am', y = "Cloud9am", data= data,kind="kde")

# %%
sns.barplot(x="WindSpeed3pm",y="Cloud3pm" ,data=data)

# %%
sns.pairplot(data=data[["Temp9am","Humidity9am","Pressure9am","Cloud9am","RainTomorrow"]],hue="RainTomorrow")

# %%
sns.countplot(x=data["RainToday"], data=data)

# %%
sns.lineplot(x='Humidity3pm', y='Pressure3pm', data=data,hue="RainTomorrow")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-29-c5c04ad6b15a> in <module>()
# ----> 1 sns.lineplot(x='Humidity3pm', y='Pressure3pm', data=data,hue="RainTomorrow")
#
# AttributeError: module 'seaborn' has no attribute 'lineplot'
